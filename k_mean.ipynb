# %%
import Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/Documents/programming/SigmaCampNext-2025`

# %%
Pkg.add(["Random","Images","Colors","MAT","LinearAlgebra","MLDatasets","CairoMakie","DataFrames"])
# Out:
#     Updating registry at `~/.julia/registries/NeurobloxRegistry`
#     Updating git-repo `https://github.com/Neuroblox/NeurobloxRegistry`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Atomix ─────── v1.1.2
#    Installed StridedViews ─ v0.4.1
#    Installed Pickle ─────── v0.3.6
#     Updating `~/Documents/programming/SigmaCampNext-2025/Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#   [eb30cadb] + MLDatasets v0.7.18
#   [9a3f8284] + Random v1.11.0
#     Updating `~/Documents/programming/SigmaCampNext-2025/Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.42
#   [dce04be8] + ArgCheck v2.5.0
#   [a9b6321e] + Atomix v1.1.2
#   [a963bdd2] + AtomsBase v0.5.1
#   [ab4f0b2a] + BFloat16s v0.5.1
#   [198e06fe] + BangBang v0.4.4
#   [9718e550] + Baselet v0.1.1
#   [d1d4a3ce] + BitFlags v0.1.9
#   [336ed68f] + CSV v0.10.15
#   [46823bd8] + Chemfiles v0.10.42
#   [a33af91c] + CompositionsBase v0.1.2
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [6add18c4] + ContextVariablesX v0.1.3
#   [a8cc5b0e] + Crayons v4.1.1
#   [124859b0] + DataDeps v0.7.13
#   [a93c6f00] + DataFrames v1.7.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [cc61a311] + FLoops v0.2.2
#   [b9860ae5] + FLoopsBase v0.1.1
#   [46192b85] + GPUArraysCore v0.2.0
#   [92fee26a] + GZip v0.6.2
#   [c27321d9] + Glob v1.3.1
#   [cd3eb016] + HTTP v1.10.17
#   [22cec73e] + InitialValues v0.3.1
#   [842dd82b] + InlineStrings v1.4.4
#   [7d512f48] + InternedStrings v0.7.0
#   [41ab1584] + InvertedIndices v1.3.1
#   [0f8b85d8] + JSON3 v1.14.3
#   [b14d175d] + JuliaVariables v0.2.4
#   [63c18a36] + KernelAbstractions v0.9.38
#   [e6f89c97] + LoggingExtras v1.1.0
#   [c2834f40] + MLCore v1.0.0
#   [eb30cadb] + MLDatasets v0.7.18
#   [d8e11817] + MLStyle v0.4.17
#   [f1d291b0] + MLUtils v0.4.8
#   [739be429] + MbedTLS v1.1.9
#   [128add7d] + MicroCollections v0.2.0
#   [872c559c] + NNlib v0.9.31
#   [15e1cf62] + NPZ v0.4.3
#   [71a1bf82] + NameResolution v0.1.5
#   [4d8831e6] + OpenSSL v1.5.0
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [7b2266bf] + PeriodicTable v1.2.1
#   [fbb45041] + Pickle v0.3.6
#   [2dfb63ee] + PooledArrays v1.4.3
#   [8162dcfd] + PrettyPrint v0.2.0
#   [08abe8d2] + PrettyTables v2.4.0
#   [91c51154] + SentinelArrays v1.4.8
#   [605ecd9f] + ShowCases v0.1.0
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [171d559e] + SplittablesBase v0.1.15
#   [4db3bf67] + StridedViews v0.4.1
#   [69024149] + StringEncodings v0.3.7
#   [892a3eda] + StringManipulation v0.4.1
#   [856f2bd8] + StructTypes v1.11.0
#   [28d57a85] + Transducers v0.4.84
#   [5c2747f8] + URIs v1.6.1
#   [a7773ee8] + UnitfulAtomic v1.0.0
#   [013be700] + UnsafeAtomics v0.3.0
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
#   [a5390f91] + ZipFile v0.10.1
#   [78a364fa] + Chemfiles_jll v0.10.4+0
# Precompiling project...
#    1053.9 ms  ✓ Atomix
#     744.1 ms  ✓ PackageExtensionCompat
#     806.0 ms  ✓ Chemfiles_jll
#     504.0 ms  ✓ InternedStrings
#     756.5 ms  ✓ BangBang → BangBangChainRulesCoreExt
#     774.1 ms  ✓ GZip
#     374.2 ms  ✓ InlineStrings → ParsersExt
#    1178.9 ms  ✓ StringManipulation
#     394.7 ms  ✓ StringEncodings
#    1289.7 ms  ✓ UnitfulAtomic
#    1291.3 ms  ✓ PeriodicTable
#     543.4 ms  ✓ BangBang → BangBangStaticArraysExt
#     603.9 ms  ✓ Accessors → StaticArraysExt
#     563.2 ms  ✓ StridedViews
#    1020.7 ms  ✓ OpenSSL
#     824.9 ms  ✓ WeakRefStrings
#     503.9 ms  ✓ StridedViews → StridedViewsPtrArraysExt
#    1920.4 ms  ✓ KernelAbstractions
#    2174.4 ms  ✓ AtomsBase
#    1800.7 ms  ✓ Pickle
#     786.6 ms  ✓ StructArrays → StructArraysGPUArraysCoreExt
#     793.8 ms  ✓ KernelAbstractions → LinearAlgebraExt
#     882.1 ms  ✓ KernelAbstractions → SparseArraysExt
#    3393.6 ms  ✓ JSON3
#    1623.7 ms  ✓ Chemfiles
#    2655.5 ms  ✓ NNlib
#     725.3 ms  ✓ NNlib → NNlibFFTWExt
#     804.3 ms  ✓ NNlib → NNlibSpecialFunctionsExt
#    7118.8 ms  ✓ CSV
#    8361.7 ms  ✓ PrettyTables
#    8039.1 ms  ✓ HTTP
#    3717.7 ms  ✓ MLUtils
#     816.0 ms  ✓ FileIO → HTTPExt
#    1500.1 ms  ✓ DataDeps
#   15699.6 ms  ✓ DataFrames
#    1094.0 ms  ✓ Transducers → TransducersDataFramesExt
#    1277.7 ms  ✓ BangBang → BangBangDataFramesExt
#    5397.1 ms  ✓ MLDatasets
#   38 dependencies successfully precompiled in 34 seconds. 417 already precompiled.

# %%
using Images, Colors, MLDatasets, CairoMakie, DataFrames

# %%
iris = Iris()
# Out:
# This program has requested access to the data dependency Iris.
# which is not currently installed. It can be installed automatically, and you will not see this message again.
#
# Dataset: The Iris dataset
# Website: https://archive.ics.uci.edu/ml/datasets/Iris
#
#
#
# Do you want to download the dataset from ["https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"] to "/Users/hstrey/.julia/scratchspaces/124859b0-ceae-595e-8997-d05f6a7a8dfe/datadeps/Iris"?
# [y/n]
# stdin>  y
# dataset Iris:
#   metadata   =>    Dict{String, Any} with 4 entries
#   features   =>    150×4 DataFrame
#   targets    =>    150×1 DataFrame
#   dataframe  =>    150×5 DataFrame

# %%
iris.features
# Out:
# 150×4 DataFrame
#  Row │ sepallength  sepalwidth  petallength  petalwidth
#      │ Float64      Float64     Float64      Float64
# ─────┼──────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2
#    2 │         4.9         3.0          1.4         0.2
#    3 │         4.7         3.2          1.3         0.2
#    4 │         4.6         3.1          1.5         0.2
#    5 │         5.0         3.6          1.4         0.2
#    6 │         5.4         3.9          1.7         0.4
#    7 │         4.6         3.4          1.4         0.3
#    8 │         5.0         3.4          1.5         0.2
#    9 │         4.4         2.9          1.4         0.2
#   10 │         4.9         3.1          1.5         0.1
#   11 │         5.4         3.7          1.5         0.2
#   ⋮  │      ⋮           ⋮            ⋮           ⋮
#  141 │         6.7         3.1          5.6         2.4
#  142 │         6.9         3.1          5.1         2.3
#  143 │         5.8         2.7          5.1         1.9
#  144 │         6.8         3.2          5.9         2.3
#  145 │         6.7         3.3          5.7         2.5
#  146 │         6.7         3.0          5.2         2.3
#  147 │         6.3         2.5          5.0         1.9
#  148 │         6.5         3.0          5.2         2.0
#  149 │         6.2         3.4          5.4         2.3
#  150 │         5.9         3.0          5.1         1.8
#                                         129 rows omitted

# %%
x = Array(iris.features)
# Out:
# 150×4 Matrix{Float64}:
#  5.1  3.5  1.4  0.2
#  4.9  3.0  1.4  0.2
#  4.7  3.2  1.3  0.2
#  4.6  3.1  1.5  0.2
#  5.0  3.6  1.4  0.2
#  5.4  3.9  1.7  0.4
#  4.6  3.4  1.4  0.3
#  5.0  3.4  1.5  0.2
#  4.4  2.9  1.4  0.2
#  4.9  3.1  1.5  0.1
#  5.4  3.7  1.5  0.2
#  4.8  3.4  1.6  0.2
#  4.8  3.0  1.4  0.1
#  ⋮
#  6.0  3.0  4.8  1.8
#  6.9  3.1  5.4  2.1
#  6.7  3.1  5.6  2.4
#  6.9  3.1  5.1  2.3
#  5.8  2.7  5.1  1.9
#  6.8  3.2  5.9  2.3
#  6.7  3.3  5.7  2.5
#  6.7  3.0  5.2  2.3
#  6.3  2.5  5.0  1.9
#  6.5  3.0  5.2  2.0
#  6.2  3.4  5.4  2.3
#  5.9  3.0  5.1  1.8

# %%
x1 = [Point3f(xx...) for xx in eachrow(x[1:50,1:3])]
x2 = [Point3f(xx...) for xx in eachrow(x[51:100,1:3])]
x3 = [Point3f(xx...) for xx in eachrow(x[101:150,1:3])]
# Out:
# 50-element Vector{Point{3, Float32}}:
#  [6.3, 3.3, 6.0]
#  [5.8, 2.7, 5.1]
#  [7.1, 3.0, 5.9]
#  [6.3, 2.9, 5.6]
#  [6.5, 3.0, 5.8]
#  [7.6, 3.0, 6.6]
#  [4.9, 2.5, 4.5]
#  [7.3, 2.9, 6.3]
#  [6.7, 2.5, 5.8]
#  [7.2, 3.6, 6.1]
#  [6.5, 3.2, 5.1]
#  [6.4, 2.7, 5.3]
#  [6.8, 3.0, 5.5]
#  ⋮
#  [6.0, 3.0, 4.8]
#  [6.9, 3.1, 5.4]
#  [6.7, 3.1, 5.6]
#  [6.9, 3.1, 5.1]
#  [5.8, 2.7, 5.1]
#  [6.8, 3.2, 5.9]
#  [6.7, 3.3, 5.7]
#  [6.7, 3.0, 5.2]
#  [6.3, 2.5, 5.0]
#  [6.5, 3.0, 5.2]
#  [6.2, 3.4, 5.4]
#  [5.9, 3.0, 5.1]

# %%
fig = Figure()
ax = Axis3(fig[1,1],
    aspect = (1, 1, 1),
    title = "Iris",
    xlabel = "Sepal length",
    ylabel = "Sepal width",
    zlabel = "Petal length")
scatter!(ax,x1, color=:red)
scatter!(ax,x2, color=:blue)
scatter!(ax,x3, color=:orange)
fig

# %%
result = kmeans(x', 3); # run K-means for the 3 clusters
result.assignments
# plot with the point color mapped to the assigned cluster index
#scatter(iris.features[!,"petallength"], iris.features[!,"petalwidth"], marker=result.assignments)
# Out:
# 150-element Vector{Int64}:
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  3
#  ⋮
#  2
#  1
#  1
#  1
#  2
#  1
#  1
#  1
#  2
#  1
#  1
#  2

# %%
xk1 = [Point3f(xx...) for (idx,xx) in enumerate(eachrow(x[:,1:3])) if result.assignments[idx] == 1]
xk2 = [Point3f(xx...) for (idx,xx) in enumerate(eachrow(x[:,1:3])) if result.assignments[idx] == 2]
xk3 = [Point3f(xx...) for (idx,xx) in enumerate(eachrow(x[:,1:3])) if result.assignments[idx] == 3]
# Out:
# 50-element Vector{Point{3, Float32}}:
#  [5.1, 3.5, 1.4]
#  [4.9, 3.0, 1.4]
#  [4.7, 3.2, 1.3]
#  [4.6, 3.1, 1.5]
#  [5.0, 3.6, 1.4]
#  [5.4, 3.9, 1.7]
#  [4.6, 3.4, 1.4]
#  [5.0, 3.4, 1.5]
#  [4.4, 2.9, 1.4]
#  [4.9, 3.1, 1.5]
#  [5.4, 3.7, 1.5]
#  [4.8, 3.4, 1.6]
#  [4.8, 3.0, 1.4]
#  ⋮
#  [4.4, 3.0, 1.3]
#  [5.1, 3.4, 1.5]
#  [5.0, 3.5, 1.3]
#  [4.5, 2.3, 1.3]
#  [4.4, 3.2, 1.3]
#  [5.0, 3.5, 1.6]
#  [5.1, 3.8, 1.9]
#  [4.8, 3.0, 1.4]
#  [5.1, 3.8, 1.6]
#  [4.6, 3.2, 1.4]
#  [5.3, 3.7, 1.5]
#  [5.0, 3.3, 1.4]

# %%
figk = Figure()
axk = Axis3(figk[1,1],
    aspect = (1, 1, 1),
    title = "Iris",
    xlabel = "Sepal length",
    ylabel = "Sepal width",
    zlabel = "Petal length")
scatter!(ax,xk1, color=:red)
scatter!(ax,xk2, color=:blue)
scatter!(ax,xk3, color=:orange)
fig

# %%
xk1
# Out:
# 39-element Vector{Point{3, Float32}}:
#  [7.0, 3.2, 4.7]
#  [6.9, 3.1, 4.9]
#  [6.7, 3.0, 5.0]
#  [6.3, 3.3, 6.0]
#  [7.1, 3.0, 5.9]
#  [6.3, 2.9, 5.6]
#  [6.5, 3.0, 5.8]
#  [7.6, 3.0, 6.6]
#  [7.3, 2.9, 6.3]
#  [6.7, 2.5, 5.8]
#  [7.2, 3.6, 6.1]
#  [6.5, 3.2, 5.1]
#  [6.4, 2.7, 5.3]
#  ⋮
#  [6.1, 2.6, 5.6]
#  [7.7, 3.0, 6.1]
#  [6.3, 3.4, 5.6]
#  [6.4, 3.1, 5.5]
#  [6.9, 3.1, 5.4]
#  [6.7, 3.1, 5.6]
#  [6.9, 3.1, 5.1]
#  [6.8, 3.2, 5.9]
#  [6.7, 3.3, 5.7]
#  [6.7, 3.0, 5.2]
#  [6.5, 3.0, 5.2]
#  [6.2, 3.4, 5.4]

# %%
xk2
# Out:
# 61-element Vector{Point{3, Float32}}:
#  [6.4, 3.2, 4.5]
#  [5.5, 2.3, 4.0]
#  [6.5, 2.8, 4.6]
#  [5.7, 2.8, 4.5]
#  [6.3, 3.3, 4.7]
#  [4.9, 2.4, 3.3]
#  [6.6, 2.9, 4.6]
#  [5.2, 2.7, 3.9]
#  [5.0, 2.0, 3.5]
#  [5.9, 3.0, 4.2]
#  [6.0, 2.2, 4.0]
#  [6.1, 2.9, 4.7]
#  [5.6, 2.9, 3.6]
#  ⋮
#  [5.7, 2.5, 5.0]
#  [5.8, 2.8, 5.1]
#  [6.0, 2.2, 5.0]
#  [5.6, 2.8, 4.9]
#  [6.3, 2.7, 4.9]
#  [6.2, 2.8, 4.8]
#  [6.1, 3.0, 4.9]
#  [6.3, 2.8, 5.1]
#  [6.0, 3.0, 4.8]
#  [5.8, 2.7, 5.1]
#  [6.3, 2.5, 5.0]
#  [5.9, 3.0, 5.1]

# %%
xk3
# Out:
# 50-element Vector{Point{3, Float32}}:
#  [5.1, 3.5, 1.4]
#  [4.9, 3.0, 1.4]
#  [4.7, 3.2, 1.3]
#  [4.6, 3.1, 1.5]
#  [5.0, 3.6, 1.4]
#  [5.4, 3.9, 1.7]
#  [4.6, 3.4, 1.4]
#  [5.0, 3.4, 1.5]
#  [4.4, 2.9, 1.4]
#  [4.9, 3.1, 1.5]
#  [5.4, 3.7, 1.5]
#  [4.8, 3.4, 1.6]
#  [4.8, 3.0, 1.4]
#  ⋮
#  [4.4, 3.0, 1.3]
#  [5.1, 3.4, 1.5]
#  [5.0, 3.5, 1.3]
#  [4.5, 2.3, 1.3]
#  [4.4, 3.2, 1.3]
#  [5.0, 3.5, 1.6]
#  [5.1, 3.8, 1.9]
#  [4.8, 3.0, 1.4]
#  [5.1, 3.8, 1.6]
#  [4.6, 3.2, 1.4]
#  [5.3, 3.7, 1.5]
#  [5.0, 3.3, 1.4]
